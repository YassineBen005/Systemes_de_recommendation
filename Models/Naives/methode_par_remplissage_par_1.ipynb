# %%
import numpy as np
import matplotlib.pyplot as plt
import math
from metrics import *
def methode_naive_1(mat):
    L=mat.copy()
    n,p=L.shape
    for i in range(n):
        for j in range(p):
            if L[i][j]==9:
                L[i][j] = 1
    return L
matrice_originale=np.loadtxt("Matrix.txt",dtype=int)
matrice_originale=np.array(matrice_originale)
L,hide = masque(matrice_originale,0.10)
for (i,j) in hide:
    L[i,j] = 9 
metrics(matrice_originale,methode_naive_1(L),hide)
# Out:
# {'Proportion correcte': 0.3894276427549123,
#  'Erreurs graves': 0.0,
#  'Précision(classe2)': 0,
#  'Recall(classe2)': 0,
#  'F-1score(classe2)': 0}
